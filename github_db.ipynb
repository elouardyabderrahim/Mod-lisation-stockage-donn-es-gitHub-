# %%
pip install psycopg2-binary
# Out:
# ...
#      ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#      --- ------------------------------------ 0.1/1.2 MB 2.6 MB/s eta 0:00:01
#      ----- ---------------------------------- 0.2/1.2 MB 1.8 MB/s eta 0:00:01
#      ------ --------------------------------- 0.2/1.2 MB 1.3 MB/s eta 0:00:01
#      -------- ------------------------------- 0.3/1.2 MB 1.4 MB/s eta 0:00:01
#      ---------- ----------------------------- 0.3/1.2 MB 1.4 MB/s eta 0:00:01
#      ------------- -------------------------- 0.4/1.2 MB 1.4 MB/s eta 0:00:01
#      ---------------- ----------------------- 0.5/1.2 MB 1.4 MB/s eta 0:00:01
#      ------------------- -------------------- 0.6/1.2 MB 1.5 MB/s eta 0:00:01
#      --------------------- ------------------ 0.6/1.2 MB 1.5 MB/s eta 0:00:01
#      --------------------- ------------------ 0.6/1.2 MB 1.4 MB/s eta 0:00:01
#      ------------------------- -------------- 0.7/1.2 MB 1.4 MB/s eta 0:00:01
# ...

# %%
import pandas as pd
import sqlalchemy as sly
import psycopg2

# %%
contributors_file_path='contributors_one.csv'
general_data_file_path='The_final_translated_data.csv'

# %%
contributors_data=pd.read_csv(contributors_file_path)
general_data=pd.read_csv(general_data_file_path)

# %% [markdown]
# #### increamenting the index

# %%
# general_data.index = range(1,len(general_data)+1)
general_data. index += 1

# %%
contributors_data.index = range(1,len(contributors_data)+1)

# %% [markdown]
# ### topics correction

# %%
import ast

# Convert the strings back to lists using ast.literal_eval
general_data['topics'] = general_data['topics'].apply(ast.literal_eval)

# Explode the 'topics' column to split the lists into individual elements
df_exploded = general_data.explode('topics')

# Reset the index of the exploded data frame
general_data = df_exploded.reset_index(drop=True)

# %%
general_data["topics"].fillna('no topics', inplace=True)

# %%
engine = sly.create_engine('postgresql+psycopg2://postgres:admin@localhost:5432/postgres')

# %%
# Write data into the table in PostgreSQL database
general_data.to_sql('githubdata',engine)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Users\Youcode\miniconda3\envs\scraping_brief\Lib\site-packages\sqlalchemy\engine\base.py:3280, in Engine._wrap_pool_connect(self, fn, connection)
#    3279 try:
# -> 3280     return fn()
#    3281 except dialect.dbapi.Error as e:
#
# File c:\Users\Youcode\miniconda3\envs\scraping_brief\Lib\site-packages\sqlalchemy\pool\base.py:310, in Pool.connect(self)
#     303 """Return a DBAPI connection from the pool.
#     304
#     305 The connection is instrumented such that when its
#    (...)
#     308
#     309 """
# --> 310 return _ConnectionFairy._checkout(self)
#
# File c:\Users\Youcode\miniconda3\envs\scraping_brief\Lib\site-packages\sqlalchemy\pool\base.py:868, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     867 if not fairy:
# --> 868     fairy = _ConnectionRecord.checkout(pool)
# ...

# %%
from sqlalchemy import text

sql = '''
    DROP TABLE githubdata;
'''
with engine.connect() as conn:
    query = conn.execute(text(sql))
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Users\Youcode\miniconda3\envs\scraping_brief\Lib\site-packages\sqlalchemy\engine\base.py:3280, in Engine._wrap_pool_connect(self, fn, connection)
#    3279 try:
# -> 3280     return fn()
#    3281 except dialect.dbapi.Error as e:
#
# File c:\Users\Youcode\miniconda3\envs\scraping_brief\Lib\site-packages\sqlalchemy\pool\base.py:310, in Pool.connect(self)
#     303 """Return a DBAPI connection from the pool.
#     304
#     305 The connection is instrumented such that when its
#    (...)
#     308
#     309 """
# --> 310 return _ConnectionFairy._checkout(self)
#
# File c:\Users\Youcode\miniconda3\envs\scraping_brief\Lib\site-packages\sqlalchemy\pool\base.py:868, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     867 if not fairy:
# --> 868     fairy = _ConnectionRecord.checkout(pool)
# ...

# %%
general_data
# Out:
#                     name                          full_name  \
# 0               HyperDbg                  HyperDbg/HyperDbg
# 1               HyperDbg                  HyperDbg/HyperDbg
# 2               HyperDbg                  HyperDbg/HyperDbg
# 3               HyperDbg                  HyperDbg/HyperDbg
# 4               HyperDbg                  HyperDbg/HyperDbg
# ...                  ...                                ...
# 96288            interim                      JD557/interim
# 96289            interim                      JD557/interim
# 96290            interim                      JD557/interim
# 96291            interim                      JD557/interim
# 96292  audiocraft-docker  ashleykleynhans/audiocraft-docker
#
#                                                      url  \
# 0                   https://github.com/HyperDbg/HyperDbg
# 1                   https://github.com/HyperDbg/HyperDbg
# 2                   https://github.com/HyperDbg/HyperDbg
# ...

# %%
contributors_data
# Out:
#        Unnamed: 0                                 src_repository  \
# 0               0                              HyperDbg/HyperDbg
# 1               1                           feelfreelinux/octo4a
# 2               2                          caseykneale/VIMKiller
# 3               3                         emilianavt/OpenSeeFace
# 4               4  aeksco/react-typescript-web-extension-starter
# ...           ...                                            ...
# 29740       29740                 chvancooten/OSEP-Code-Snippets
# 29741       29741                                     wgpsec/tig
# 29742       29742                                Phineas/lanyard
# 29743       29743                             fingerprintjs/BotD
# 29744       29744                            QuiltMC/quiltflower
#
#         contributor  number_of_contributions
# 0            xorrsp                      1.0
# 1            xeijin                      1.0
# 2           LeafyLi                      1.0
# ...

# %% [markdown]
# ### Contributors dataFrame clean and correct columns

# %%
import pandas as pd
import ast

# Given data frame
data =contributors_data["contributors"].to_frame()

df = pd.DataFrame(data)

# Function to extract values from the 'contributors' column
# Function to extract values from the 'contributors' column
def extract_contributor_info(row):
    if pd.notnull(row['contributors']):
        contributor_info = ast.literal_eval(row['contributors'])
        return pd.Series(contributor_info)
    else:
        return pd.Series({'src_repository': None, 'contributor': None, 'number_of_contributions': None})

# Applying the function to extract new columns
df[['src_repository', 'contributor', 'number_of_contributions']] = df.apply(extract_contributor_info, axis=1)

# Dropping the original 'contributors' column
df = df.drop(columns=['contributors'])

print(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\miniconda3\envs\scraping_brief\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\miniconda3\envs\scraping_brief\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\miniconda3\envs\scraping_brief\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'contributors'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
contributors_data.drop(contributors_data.columns[contributors_data.columns.str.contains('unnamed',case = False)],axis = 1, inplace = True)

# %% [markdown]
# ### Add Ids to tables for insertion:

# %%
# old methode 
df = df.reset_index()
df = df.rename(columns={"index":"contributor_ID"})
df['contributor_ID'] = df.index + 1

# %%
contributors_data
# Out:
#        Unnamed: 0                                 src_repository  \
# 0               0                              HyperDbg/HyperDbg
# 1               1                           feelfreelinux/octo4a
# 2               2                          caseykneale/VIMKiller
# 3               3                         emilianavt/OpenSeeFace
# 4               4  aeksco/react-typescript-web-extension-starter
# ...           ...                                            ...
# 29740       29740                 chvancooten/OSEP-Code-Snippets
# 29741       29741                                     wgpsec/tig
# 29742       29742                                Phineas/lanyard
# 29743       29743                             fingerprintjs/BotD
# 29744       29744                            QuiltMC/quiltflower
#
#         contributor  number_of_contributions
# 0            xorrsp                      1.0
# 1            xeijin                      1.0
# 2           LeafyLi                      1.0
# ...

# %% [markdown]
# #### adding contributor id

# %%
contributors_data['contributor_id'] = contributors_data['contributor'].astype('category').cat.codes

# %%
contributors_data["number_of_contributions"]=contributors_data["number_of_contributions"].astype(pd.Int64Dtype())

# %%
contributors_data.dropna(inplace=True)

# %%
contributors_data.to_csv("contributors_data.csv",index=False)

# %% [markdown]
# #### adding general_data ids

# %%
general_data['repo_id'] = general_data['full_name'].astype('category').cat.codes

# %%
general_data['language_id'] = general_data['language'].astype('category').cat.codes

# %%
general_data['license_id'] = general_data['license'].astype('category').cat.codes

# %%
general_data['topics_id'] = general_data['topics'].astype('category').cat.codes

# %%
general_data['owner_id'] = general_data['owner_Name'].astype('category').cat.codes

# %%
general_data
# Out:
#                     name                          full_name  \
# 0               HyperDbg                  HyperDbg/HyperDbg
# 1               HyperDbg                  HyperDbg/HyperDbg
# 2               HyperDbg                  HyperDbg/HyperDbg
# 3               HyperDbg                  HyperDbg/HyperDbg
# 4               HyperDbg                  HyperDbg/HyperDbg
# ...                  ...                                ...
# 96288            interim                      JD557/interim
# 96289            interim                      JD557/interim
# 96290            interim                      JD557/interim
# 96291            interim                      JD557/interim
# 96292  audiocraft-docker  ashleykleynhans/audiocraft-docker
#
#                                                      url  \
# 0                   https://github.com/HyperDbg/HyperDbg
# 1                   https://github.com/HyperDbg/HyperDbg
# 2                   https://github.com/HyperDbg/HyperDbg
# ...

# %%
general_data[['owner_Name', 'repo_Name']] = general_data["full_name"].apply(lambda x: pd.Series(str(x).split("/")))

# %%
contributors_data_end_file=pd.read_csv("contributors_data.csv")

# %%
contributors_data_end_file.rename(columns={'src_repository': 'full_name_repository',}, inplace=True)
general_data.rename(columns={'full_name': 'full_name_repository',}, inplace=True)

# %%
# general_data.drop(['full_name'], inplace=True, axis=1)
general_data.drop(['name'], inplace=True, axis=1)

# %%
data_ready_to_insert=pd.merge(general_data, contributors_data_end_file, on='full_name_repository')

# %%
data_ready_to_insert["contributor"].fillna("no_contributor",inplace=True)
data_ready_to_insert["number_of_contributions"].fillna(0,inplace=True)

# %%
data_ready_to_insert[data_ready_to_insert["contributor"]=="no_contributor"]
# Out:
# Empty DataFrame
# Columns: [full_name_repository, url, description, stars, created_at, language, forks, updated_at, topics, license, type_of_owner, repo_id, language_id, license_id, topics_id, owner_Name, repo_Name, Unnamed: 0, contributor, number_of_contributions, contributor_id]
# Index: []
#
# [0 rows x 21 columns]

# %%
data_ready_to_insert.describe()
# Out:
#               stars         forks       repo_id   language_id    license_id  \
# count  83503.000000  83503.000000  83503.000000  83503.000000  83503.000000
# mean     510.255105     87.346227  12034.374142    103.133157     14.292995
# std     1835.785952    467.654389   6912.945979     47.404860     10.891544
# min        8.000000      0.000000      0.000000      0.000000      0.000000
# 25%       82.000000     10.000000   6038.500000     71.000000      3.000000
# 50%      150.000000     25.000000  12106.000000    120.000000     18.000000
# 75%      349.000000     61.000000  18019.000000    139.000000     23.000000
# max    52024.000000  31423.000000  23999.000000    174.000000     36.000000
#
#           topics_id  number_of_contributions  contributor_id
# count  83503.000000             83503.000000    83503.000000
# mean   14200.462762                35.913069     9050.856209
# std     7502.071486               248.621250     5146.433061
# ...

# %%
data_ready_to_insert.drop(data_ready_to_insert.columns[data_ready_to_insert.columns.str.contains('unnamed',case = False)],axis = 1, inplace = True)

# %%
data_ready_to_insert.drop_duplicates(inplace=True)

# %%
data_ready_to_insert.dropna()
# Out:
#                      full_name_repository  \
# 0                       HyperDbg/HyperDbg
# 2                       HyperDbg/HyperDbg
# 4                       HyperDbg/HyperDbg
# 6                       HyperDbg/HyperDbg
# 8                       HyperDbg/HyperDbg
# ...                                   ...
# 122638                      JD557/interim
# 122639                      JD557/interim
# 122640                      JD557/interim
# 122641                      JD557/interim
# 122642  ashleykleynhans/audiocraft-docker
#
#                                                       url  \
# 0                    https://github.com/HyperDbg/HyperDbg
# 2                    https://github.com/HyperDbg/HyperDbg
# 4                    https://github.com/HyperDbg/HyperDbg
# 6                    https://github.com/HyperDbg/HyperDbg
# 8                    https://github.com/HyperDbg/HyperDbg
# ...                                                   ...
# ...

# %%
data_ready_to_insert.to_csv("data_ready_to_insert.csv",index=False)

# %% [markdown]
# # Tables creation

# %%
# Create the engine to connect to the PostgreSQL database
#‘postgresql://username:password@databasehost:port/databasename’
engine = sly.create_engine('postgresql+psycopg2://postgres:admin@localhost:5432/brief-four')

# %%
from sqlalchemy import text
# Owners
sql = '''
    CREATE TABLE "Owners" (
  "owner_id" INT PRIMARY KEY NOT NULL,
  "owner_Name" TEXT   NOT NULL,
  "type_of_owner" TEXT  NOT NULL
);
'''
with engine.connect() as conn:
    query = conn.execute(text(sql))

# %%
# Contributors
with engine.connect() as conn:
    query = conn.execute(text('''
  CREATE TABLE "Contributors" (
  "contributor_id" INT PRIMARY KEY NOT NULL,
  "contributor" TEXT NOT NULL);
'''))

# %%
# Languages
with engine.connect() as conn:
    query = conn.execute(text('''
    CREATE TABLE "Languages" (
  "language_id" INT PRIMARY KEY NOT NULL,
  "language_name" TEXT NOT NULL
);
'''))

# %%
# Licences
with engine.connect() as conn:
    query = conn.execute(text('''
  DROP TABLE IF EXISTS  Licences ;
 CREATE TABLE "Licences" (
  "license_id" INT PRIMARY KEY NOT NULL,
  "license" TEXT NOT NULL
);
'''))
# Out:
# ---------------------------------------------------------------------------
# DuplicateTable                            Traceback (most recent call last)
# File c:\Users\Youcode\miniconda3\envs\scraping_brief\Lib\site-packages\sqlalchemy\engine\base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#
# File c:\Users\Youcode\miniconda3\envs\scraping_brief\Lib\site-packages\sqlalchemy\engine\default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# DuplicateTable: ERREUR:  la relation « Licences » existe déjà
#
#
# ...

# %%
# Topics
with engine.connect() as conn:
    query = conn.execute(text('''
 CREATE TABLE "Topics" (
  "topic_Id" INT PRIMARY KEY NOT NULL,
  "topics" TEXT  NOT NULL
);
 '''))

# %%
with engine.connect() as conn:
    query = conn.execute(text('''
DROP TABLE IF EXISTS  Repositories ;
CREATE TABLE "Repositories" (
  "repo_id" INT PRIMARY KEY NOT NULL,
  "repo_Name" TEXT  NOT NULL,
  "url" TEXT  NOT NULL,
  "description" TEXT,
  "stars" INT,
  "created_at" date,
  "forks" INT,
  "updated_at" date,
  "owner_id" INT NOT NULL,
  "license_id" INT NOT NULL,
  "language_id" INT NOT NULL ,
  CONSTRAINT "FK_Repositories.language_id"
    FOREIGN KEY ("language_id")
      REFERENCES "Languages"("language_id"),
  CONSTRAINT "FK_Repositories.license_id"
    FOREIGN KEY ("license_id")
      REFERENCES "Licences"("license_id"),
  CONSTRAINT "FK_Repositories.owner_ID"
    FOREIGN KEY ("owner_id")
      REFERENCES "Owners"("owner_id")
);


'''))
# Out:
# ---------------------------------------------------------------------------
# DuplicateTable                            Traceback (most recent call last)
# File c:\Users\Youcode\miniconda3\envs\scraping_brief\Lib\site-packages\sqlalchemy\engine\base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#
# File c:\Users\Youcode\miniconda3\envs\scraping_brief\Lib\site-packages\sqlalchemy\engine\default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# DuplicateTable: ERREUR:  la relation « Repositories » existe déjà
#
#
# ...

# %%
with engine.connect() as conn:
    query = conn.execute(text('''

CREATE TABLE "Repositories_contributors" (
  "contributor_id" INT NOT NULL,
  "repo_id" INT NOT NULL,
  "number_of_contributions" INT ,
  CONSTRAINT "FK_Repositories_contributors.contributor_id"
    FOREIGN KEY ("contributor_id")
      REFERENCES "Contributors"("contributor_id"),
  CONSTRAINT "FK_Repositories_contributors.Id_Repo"
    FOREIGN KEY ("repo_id")
      REFERENCES "Repositories"("repo_id")
);

CREATE INDEX "INDEX_FK/PK_Repositories_contributors" ON  "Repositories_contributors" ("contributor_id", "repo_id");


'''))

# %%
with engine.connect() as conn:
    query = conn.execute(text(''' 
CREATE TABLE "Topic_Repositories" (
  "repo_id" INT NOT NULL,
  "topic_Id" INT NOT NULL,
  CONSTRAINT "FK_Topic_Repositories.repo_id"
    FOREIGN KEY ("repo_id")
      REFERENCES "Repositories"("repo_id"),
  CONSTRAINT "FK_Topic_Repositories.topic_Id"
    FOREIGN KEY ("topic_Id")
      REFERENCES "Topics"("topic_Id")
);
  CREATE INDEX "INDEX_FK/PK_Topic_Repositories" ON  "Topic_Repositories" ("repo_id", "topic_Id");

'''
))  


#

# %% [markdown]
# # Data insertion

# %%
data_ready_to_insert['owner_id'] = data_ready_to_insert['owner_Name'].astype('category').cat.codes

# %%
# data_ready_to_insert.rename(columns = {'language':'language_name'}, inplace = True)

# %%
data_ready_to_insert
# Out:
#                      full_name_repository  \
# 0                       HyperDbg/HyperDbg
# 2                       HyperDbg/HyperDbg
# 4                       HyperDbg/HyperDbg
# 6                       HyperDbg/HyperDbg
# 8                       HyperDbg/HyperDbg
# ...                                   ...
# 122638                      JD557/interim
# 122639                      JD557/interim
# 122640                      JD557/interim
# 122641                      JD557/interim
# 122642  ashleykleynhans/audiocraft-docker
#
#                                                       url  \
# 0                    https://github.com/HyperDbg/HyperDbg
# 2                    https://github.com/HyperDbg/HyperDbg
# 4                    https://github.com/HyperDbg/HyperDbg
# 6                    https://github.com/HyperDbg/HyperDbg
# 8                    https://github.com/HyperDbg/HyperDbg
# ...                                                   ...
# ...

# %%
# Topics :
df_Topics_table=data_ready_to_insert[['topics_id','topics']]

# %%
df_Topics_table.drop_duplicates(inplace=True)
# Out:
# C:\Users\Youcode\AppData\Local\Temp\ipykernel_5896\2297140492.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_Topics_table.drop_duplicates(inplace=True)

# %%
display(df_Topics_table)
# Out:
#         topic_Id            topics
# 0           6060             debug
# 2           6062          debugger
# 4           7847               ept
# 6          11117              hook
# 8          11355          hyperdbg
# ...          ...               ...
# 122616      8032  event-extraction
# 122617      9950    global-pointer
# 122618     10249          gplinker
# 122627     17367          original
# 122641     21244      scala-native
#
# [25551 rows x 2 columns]

# %%
df_Topics_table.rename(columns = {'topics_Id':'topic_Id'}, inplace = True)
# Out:
# C:\Users\Youcode\AppData\Local\Temp\ipykernel_5896\175304887.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_Topics_table.rename(columns = {'topics_Id':'topic_Id'}, inplace = True)

# %%
df_Topics_table.to_sql('Topics', engine, if_exists='append',index=False)


# df.to_sql('db_table2', engine, if_exists='append')
# from docstring:

# """
# if_exists : {'fail', 'replace', 'append'}, default 'fail'
#     - fail: If table exists, do nothing.
#     - replace: If table exists, drop it, recreate it, and insert data.
#     - append: If table exists, insert data. Create if does not exist.
# """
# Out:
# 551

# %% [markdown]
# ## languages

# %%
'''
  language_id
  language_name

''' 

df_language_table=data_ready_to_insert[['language_id','language']]

# %%
df_language_table.rename(columns = {'language':'language_name'}, inplace = True)
# Out:
# C:\Users\Youcode\AppData\Local\Temp\ipykernel_5896\3517761141.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_language_table.rename(columns = {'language':'language_name'}, inplace = True)

# %%
df_language_table.drop_duplicates(inplace=True)
# Out:
# C:\Users\Youcode\AppData\Local\Temp\ipykernel_5896\1396729110.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_language_table.drop_duplicates(inplace=True)

# %%
df_language_table.to_sql('Languages', engine, if_exists='append',index=False)
# Out:
# 168

# %%
# Owners
"""
 "owner_id" 
  "owner_Name" 
  "type_of_owner" 
"""
df_Owners_table=data_ready_to_insert[['owner_id','owner_Name','type_of_owner']]
# df_Owners_table.rename(columns = {'language':'language_name'}, inplace = True)
df_Owners_table.drop_duplicates(inplace=True)
# Out:
# C:\Users\Youcode\AppData\Local\Temp\ipykernel_5896\4001810140.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_Owners_table.drop_duplicates(inplace=True)

# %%
df_Owners_table.to_sql('Owners', engine, if_exists='append',index=False)
# Out:
# 116

# %%
df_Owners_table
# Out:
#         owner_id       owner_Name type_of_owner
# 0           2014         HyperDbg  Organization
# 16          8298    feelfreelinux          User
# 22          6604      caseykneale          User
# 24          8036       emilianavt          User
# 64          5242           aeksco          User
# ...          ...              ...           ...
# 122633     13449        radkesvat          User
# 122635      3878       SSJACK8582          User
# 122636     10102  johncoffeeocean          User
# 122637      2132            JD557          User
# 122642      5853  ashleykleynhans          User
#
# [17116 rows x 3 columns]

# %% [markdown]
# ## Licence

# %%
df_licence_table=data_ready_to_insert[['license_id','license']]

# %%
df_licence_table
# Out:
#         license_id                                            license
# 0               18  {'key': 'gpl-3.0', 'name': 'GNU General Public...
# 2               18  {'key': 'gpl-3.0', 'name': 'GNU General Public...
# 4               18  {'key': 'gpl-3.0', 'name': 'GNU General Public...
# 6               18  {'key': 'gpl-3.0', 'name': 'GNU General Public...
# 8               18  {'key': 'gpl-3.0', 'name': 'GNU General Public...
# ...            ...                                                ...
# 122638          23  {'key': 'mit', 'name': 'MIT License', 'spdx_id...
# 122639          23  {'key': 'mit', 'name': 'MIT License', 'spdx_id...
# 122640          23  {'key': 'mit', 'name': 'MIT License', 'spdx_id...
# 122641          23  {'key': 'mit', 'name': 'MIT License', 'spdx_id...
# 122642          18  {'key': 'gpl-3.0', 'name': 'GNU General Public...
#
# [83503 rows x 2 columns]

# %%
df_licence_table.drop_duplicates(inplace=True)
# Out:
# C:\Users\Youcode\AppData\Local\Temp\ipykernel_5896\263183528.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_licence_table.drop_duplicates(inplace=True)

# %%
df_licence_table.drop('index', inplace=True, axis=1)
# Out:
# C:\Users\Youcode\AppData\Local\Temp\ipykernel_5896\1117761987.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_licence_table.drop('index', inplace=True, axis=1)

# %%
df_licence_table
# Out:
#         license_id                                            license
# 0               18  {'key': 'gpl-3.0', 'name': 'GNU General Public...
# 16               2  {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...
# 22              23  {'key': 'mit', 'name': 'MIT License', 'spdx_id...
# 24               5  {'key': 'bsd-2-clause', 'name': 'BSD 2-Clause ...
# 120              0                                         no_license
# 184             31  {'key': 'other', 'name': 'Other', 'spdx_id': '...
# 212              3  {'key': 'apache-2.0', 'name': 'Apache License ...
# 236             25  {'key': 'mpl-2.0', 'name': 'Mozilla Public Lic...
# 276              6  {'key': 'bsd-3-clause', 'name': 'BSD 3-Clause ...
# 1264            19  {'key': 'isc', 'name': 'ISC License', 'spdx_id...
# 1422            33  {'key': 'unlicense', 'name': 'The Unlicense', ...
# 1628            17  {'key': 'gpl-2.0', 'name': 'GNU General Public...
# ...

# %%
df_licence_table.to_sql('Licences', engine, if_exists='append',index=False)
# Out:
# 36

# %%
import ast  # This module is used to safely evaluate the string representation of the dictionaries

# Sample data (replace this with your actual DataFrame)



# Convert the string representation of dictionaries to actual dictionaries
df_licence_table['license'] = df_licence_table['license'].apply(ast.literal_eval)

# Create an empty dictionary to store the data for the new DataFrame
new_data = {'license_id': df_licence_table['license_id'].tolist()}

# Iterate through the rows of the DataFrame to extract the data for the new DataFrame
for index, row in df_licence_table.iterrows():
    license_info = row['license']
    for key, value in license_info.items():
        if key not in new_data:
            new_data[key] = []
        new_data[key].append(value)

# Create the new DataFrame from the dictionary
new_df = pd.DataFrame(new_data)

print(new_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[169], line 8
#       1 import ast  # This module is used to safely evaluate the string representation of the dictionaries
#       3 # Sample data (replace this with your actual DataFrame)
#       4
#       5
#       6
#       7 # Convert the string representation of dictionaries to actual dictionaries
# ----> 8 df_licence_table['license'] = df_licence_table['license'].apply(ast.literal_eval)
#      10 # Create an empty dictionary to store the data for the new DataFrame
#      11 new_data = {'license_id': df_licence_table['license_id'].tolist()}
#
# File c:\Users\Youcode\miniconda3\envs\scraping_brief\Lib\site-packages\pandas\core\series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
# ...

# %% [markdown]
# ### Repositories Table

# %%
with engine.connect() as conn:
    query = conn.execute(text('''
	ALTER TABLE public."Repositories" DROP COLUMN watchers
'''))

# %%
"""# Repository
"repo_id" ,
  "repo_Name" ,
  "url" ,
  "description",
  "stars" ,
  "created_at",
  "forks" ,
  "watchers", 
  "updated_at",
  "open_issues" ,
  "owner_id" ,
  "license_id" ,
  "language_id" 

"""


df_repo_table=data_ready_to_insert[["repo_id" ,"repo_Name" ,"url" ,"description","stars" ,"created_at", 
                                    "forks" , "updated_at" ,"owner_id" ,"license_id" ,"language_id"]]

# %%
df_repo_table.drop_duplicates(inplace=True)
# Out:
# C:\Users\Youcode\AppData\Local\Temp\ipykernel_5896\1651343521.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_repo_table.drop_duplicates(inplace=True)

# %%
df_repo_table.to_sql('Repositories', engine, if_exists='append',index=False)
# Out:
# 640

# %%
df_repo_table
# Out:
#         repo_id                               repo_Name  \
# 0          2766                                HyperDbg
# 16        11741                                  octo4a
# 22         9326                               VIMKiller
# 24        11310                             OpenSeeFace
# 64         7317  react-typescript-web-extension-starter
# ...         ...                                     ...
# 122634    19617                        seed-wyse-vector
# 122635     5383                         jd_ql_assistant
# 122636    14241        dating_app_moonmeet_react_native
# 122637     2929                                 interim
# 122642     8225                       audiocraft-docker
#
#                                                       url  \
# 0                    https://github.com/HyperDbg/HyperDbg
# 16                https://github.com/feelfreelinux/octo4a
# 22               https://github.com/caseykneale/VIMKiller
# ...

# %% [markdown]
# ## Contributors

# %%
df_contr_table=data_ready_to_insert[["contributor_id","contributor"]]

# %%
df_contr_table.drop_duplicates(inplace=True)
# Out:
# C:\Users\Youcode\AppData\Local\Temp\ipykernel_5896\4115263305.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_contr_table.drop_duplicates(inplace=True)

# %%
df_contr_table.to_sql('Contributors', engine, if_exists='append',index=False)
# Out:
# 273

# %% [markdown]
# ## Relation tables

# %% [markdown]
# ### Topic_Repositories

# %%
repo_topic_table=data_ready_to_insert[["topics_id","repo_id"]]

# %%
repo_topic_table.rename(columns={'topics_id': 'topic_Id',}, inplace=True)
# Out:
# C:\Users\Youcode\AppData\Local\Temp\ipykernel_5896\3325410983.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   repo_topic_table.rename(columns={'topics_id': 'topic_Id',}, inplace=True)

# %%
repo_topic_table.drop_duplicates(inplace=True)
# Out:
# C:\Users\Youcode\AppData\Local\Temp\ipykernel_5896\4165589955.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   repo_topic_table.drop_duplicates(inplace=True)

# %%
repo_topic_table.to_sql('Topic_Repositories', engine, if_exists='append',index=False)
# Out:
# 409

# %% [markdown]
# ### repository contributors

# %%
repo_cont_table=data_ready_to_insert[["contributor_id","repo_id","number_of_contributions"]]
repo_cont_table
# Out:
#         contributor_id  repo_id  number_of_contributions
# 0                17381     2766                        1
# 2                17381     2766                        1
# 4                17381     2766                        1
# 6                17381     2766                        1
# 8                17381     2766                        1
# ...                ...      ...                      ...
# 122638           14563     2929                        7
# 122639           14563     2929                        7
# 122640           14563     2929                        7
# 122641           14563     2929                        7
# 122642            5436     8225                       12
#
# [83503 rows x 3 columns]

# %%
repo_cont_table.drop_duplicates(inplace=True)
# Out:
# C:\Users\Youcode\AppData\Local\Temp\ipykernel_5896\3535837784.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   repo_cont_table.drop_duplicates(inplace=True)

# %%
repo_cont_table
# Out:
#         contributor_id  repo_id  number_of_contributions
# 0                17381     2766                        1
# 16               17270    11741                        1
# 22                2232     9326                        1
# 24               17476    11310                        1
# 64                4343     7317                        1
# ...                ...      ...                      ...
# 122634           14227    19617                     3089
# 122635            3407     5383                        7
# 122636            9738    14241                     1061
# 122637           14563     2929                        7
# 122642            5436     8225                       12
#
# [20666 rows x 3 columns]

# %%
repo_cont_table.to_sql('Repositories_contributors', engine, if_exists='append',index=False)
