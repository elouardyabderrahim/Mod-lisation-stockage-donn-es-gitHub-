# %%
import pandas as pd
import sqlalchemy as sly
contributors_file_path='C:/Users/Youcode/Desktop/cleaning_gethub_data/df_contributors_src.csv'
general_data_file_path='C:/Users/Youcode/Desktop/cleaning_gethub_data/The_final_translated_data.csv'
# Create the engine to connect to the PostgreSQL database
#‘postgresql://username:password@databasehost:port/databasename’
engine = sly.create_engine('postgresql://postgres:admin@localhost:5432/postgres')

# %%
general_data=pd.read_csv(general_data_file_path)
contributors_data=pd.read_csv(contributors_file_path)

# %%
# Write data into the table in PostgreSQL database
general_data.to_sql('githubdata',engine)

# %%
from sqlalchemy import text

sql = '''
    DROP TABLE superstore;
'''
with engine.connect() as conn:
    query = conn.execute(text(sql))

# %%
general_data
# Out:
#                                          name  \
# 0                                    HyperDbg
# 1                                      octo4a
# 2                                   VIMKiller
# 3                                 OpenSeeFace
# 4      react-typescript-web-extension-starter
# ...                                       ...
# 23995                        seed-wyse-vector
# 23996                         jd_ql_assistant
# 23997        dating_app_moonmeet_react_native
# 23998                                 interim
# 23999                       audiocraft-docker
#
#                                               full_name  \
# 0                                     HyperDbg/HyperDbg
# 1                                  feelfreelinux/octo4a
# 2                                 caseykneale/VIMKiller
# 3                                emilianavt/OpenSeeFace
# 4         aeksco/react-typescript-web-extension-starter
# ...                                                 ...
# 23995                     ruikishimoto/seed-wyse-vector
# 23996                        SSJACK8582/jd_ql_assistant
# 23997  johncoffeeocean/dating_app_moonmeet_react_native
# 23998                                     JD557/interim
# 23999                 ashleykleynhans/audiocraft-docker
#
#                                                      url  \
# 0                   https://github.com/HyperDbg/HyperDbg
# 1                https://github.com/feelfreelinux/octo4a
# 2               https://github.com/caseykneale/VIMKiller
# 3              https://github.com/emilianavt/OpenSeeFace
# 4      https://github.com/aeksco/react-typescript-web...
# ...                                                  ...
# 23995   https://github.com/ruikishimoto/seed-wyse-vector
# 23996      https://github.com/SSJACK8582/jd_ql_assistant
# 23997  https://github.com/johncoffeeocean/dating_app_...
# 23998                   https://github.com/JD557/interim
# 23999  https://github.com/ashleykleynhans/audiocraft-...
#
#                                              description  stars  \
# 0                 State-of-the-art native debugging tool   2173
# 1      Use your old Android device as an OctoPrint se...   1265
# 2      Exiting VIM is hard; sometimes we need to take...   1159
# 3      Robust realtime face and facial landmark track...   1105
# 4      :desktop_computer: Web Extension starter kit b...    805
# ...                                                  ...    ...
# 23995                                     no_description      9
# 23996                                           京东青龙抢购助手      9
# 23997                                     no_description      9
# 23998                   Immediate mode GUI in pure Scala      9
# 23999  Docker image for Audiocraft audio processing a...      8
#
#                       created_at    language  forks  \
# 0      2020-01-01 12:34:32+00:00           C    317
# 1      2020-01-01 17:00:11+00:00      Kotlin    123
# 2      2020-01-01 01:31:29+00:00       Julia     13
# 3      2020-01-01 12:49:35+00:00      Python    134
# 4      2020-01-01 01:14:35+00:00  JavaScript     73
# ...                          ...         ...    ...
# 23995  2023-06-10 02:19:31+00:00         PHP      0
# 23996  2023-06-10 13:05:14+00:00      Python      2
# 23997  2023-06-10 04:59:10+00:00  JavaScript      0
# 23998  2023-06-10 14:38:21+00:00       Scala      1
# 23999  2023-06-10 13:07:46+00:00  Dockerfile      0
#
#                       updated_at  \
# 0      2023-06-23 10:17:49+00:00
# 1      2023-06-21 22:24:04+00:00
# 2      2023-06-21 16:37:23+00:00
# 3      2023-06-23 11:37:45+00:00
# 4      2023-06-18 12:59:14+00:00
# ...                          ...
# 23995  2023-06-23 14:55:57+00:00
# 23996  2023-06-20 07:48:09+00:00
# 23997  2023-06-23 15:01:38+00:00
# 23998  2023-06-19 12:14:26+00:00
# 23999  2023-06-21 03:24:33+00:00
#
#                                                   topics  \
# 0      ['debug', 'debugger', 'ept', 'hook', 'hyperdbg...
# 1                ['3d-printing', 'android', 'octoprint']
# 2                                                     []
# 3      ['cpu', 'csharp', 'depth-estimation', 'detecti...
# 4      ['brave', 'chrome-extension', 'eslint', 'exten...
# ...                                                  ...
# 23995                                                 []
# 23996                                                 []
# 23997                                                 []
# 23998  ['gui', 'immediate-gui', 'scala', 'scala-js', ...
# 23999                                                 []
#
#                                                  license type_of_owner
# 0      {'key': 'gpl-3.0', 'name': 'GNU General Public...  Organization
# 1      {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...          User
# 2      {'key': 'mit', 'name': 'MIT License', 'spdx_id...          User
# 3      {'key': 'bsd-2-clause', 'name': 'BSD 2-Clause ...          User
# 4      {'key': 'mit', 'name': 'MIT License', 'spdx_id...          User
# ...                                                  ...           ...
# 23995  {'key': 'other', 'name': 'Other', 'spdx_id': '...          User
# 23996                                         no_license          User
# 23997  {'key': 'gpl-3.0', 'name': 'GNU General Public...          User
# 23998  {'key': 'mit', 'name': 'MIT License', 'spdx_id...          User
# 23999  {'key': 'gpl-3.0', 'name': 'GNU General Public...          User
#
# [24000 rows x 12 columns]

# %%
contributors_data
# Out:
#        Unnamed: 0                                       contributors
# 0               0  {'src_repository': 'HyperDbg/HyperDbg', 'contr...
# 1               1  {'src_repository': 'feelfreelinux/octo4a', 'co...
# 2               2  {'src_repository': 'caseykneale/VIMKiller', 'c...
# 3               3  {'src_repository': 'emilianavt/OpenSeeFace', '...
# 4               4  {'src_repository': 'aeksco/react-typescript-we...
# ...           ...                                                ...
# 29740       29740  {'src_repository': 'chvancooten/OSEP-Code-Snip...
# 29741       29741  {'src_repository': 'wgpsec/tig', 'contributor'...
# 29742       29742  {'src_repository': 'Phineas/lanyard', 'contrib...
# 29743       29743  {'src_repository': 'fingerprintjs/BotD', 'cont...
# 29744       29744  {'src_repository': 'QuiltMC/quiltflower', 'con...
#
# [29745 rows x 2 columns]

# %%
contributors=contributors_data["contributors"].to_frame()

# %%
# Out:
#                                             contributors
# 0      {'src_repository': 'HyperDbg/HyperDbg', 'contr...
# 1      {'src_repository': 'feelfreelinux/octo4a', 'co...
# 2      {'src_repository': 'caseykneale/VIMKiller', 'c...
# 3      {'src_repository': 'emilianavt/OpenSeeFace', '...
# 4      {'src_repository': 'aeksco/react-typescript-we...
# ...                                                  ...
# 29740  {'src_repository': 'chvancooten/OSEP-Code-Snip...
# 29741  {'src_repository': 'wgpsec/tig', 'contributor'...
# 29742  {'src_repository': 'Phineas/lanyard', 'contrib...
# 29743  {'src_repository': 'fingerprintjs/BotD', 'cont...
# 29744  {'src_repository': 'QuiltMC/quiltflower', 'con...
#
# [29745 rows x 1 columns]

# %%
df=pd.read_csv("contributors_one.csv")

# %% [markdown]
# ### Contributors dataFrame clean and correct columns

# %%
import pandas as pd
import ast

# Given data frame
data =contributors_data["contributors"].to_frame()

df = pd.DataFrame(data)

# Function to extract values from the 'contributors' column
# Function to extract values from the 'contributors' column
def extract_contributor_info(row):
    if pd.notnull(row['contributors']):
        contributor_info = ast.literal_eval(row['contributors'])
        return pd.Series(contributor_info)
    else:
        return pd.Series({'src_repository': None, 'contributor': None, 'number_of_contributions': None})

# Applying the function to extract new columns
df[['src_repository', 'contributor', 'number_of_contributions']] = df.apply(extract_contributor_info, axis=1)

# Dropping the original 'contributors' column
df = df.drop(columns=['contributors'])

print(df)
# Out:
#                                       src_repository   contributor  \
# 0                                  HyperDbg/HyperDbg        xorrsp
# 1                               feelfreelinux/octo4a        xeijin
# 2                              caseykneale/VIMKiller       LeafyLi
# 3                             emilianavt/OpenSeeFace   yamichan420
# 4      aeksco/react-typescript-web-extension-starter  WillKirkmanM
# ...                                              ...           ...
# 29740                 chvancooten/OSEP-Code-Snippets       Pal1Sec
# 29741                                     wgpsec/tig         wikiZ
# 29742                                Phineas/lanyard        geenva
# 29743                             fingerprintjs/BotD      tarunama
# 29744                            QuiltMC/quiltflower     egorzhdan
#
#        number_of_contributions
# 0                          1.0
# 1                          1.0
# 2                          1.0
# 3                          1.0
# 4                          1.0
# ...                        ...
# 29740                      1.0
# 29741                      3.0
# 29742                      2.0
# 29743                      1.0
# 29744                      2.0
#
# [29745 rows x 3 columns]

# %%
df["number_of_contributions"]=df["number_of_contributions"].astype(pd.Int64Dtype())

# %%
df.to_csv("contributors_one.csv")

# %% [markdown]
# ### Add Ids to tables for insertion:

# %%
df = df.reset_index()
df = df.rename(columns={"index":"contributor_ID"})
df['contributor_ID'] = df.index + 1

# %%
df.drop(['id'], inplace=True, axis=1)

# %%
df.dropna(inplace=True)

# %%
df['contributor_id'] = df['contributor'].astype('category').cat.codes

# %%
df
# Out:
#                                       src_repository   contributor  \
# 0                                  HyperDbg/HyperDbg        xorrsp
# 1                               feelfreelinux/octo4a        xeijin
# 2                              caseykneale/VIMKiller       LeafyLi
# 3                             emilianavt/OpenSeeFace   yamichan420
# 4      aeksco/react-typescript-web-extension-starter  WillKirkmanM
# ...                                              ...           ...
# 29740                 chvancooten/OSEP-Code-Snippets       Pal1Sec
# 29741                                     wgpsec/tig         wikiZ
# 29742                                Phineas/lanyard        geenva
# 29743                             fingerprintjs/BotD      tarunama
# 29744                            QuiltMC/quiltflower     egorzhdan
#
#        number_of_contributions  contributor_id
# 0                            1           17381
# 1                            1           17270
# 2                            1            2232
# 3                            1           17476
# 4                            1            4343
# ...                        ...             ...
# 29740                        1            2980
# 29741                        3           16993
# 29742                        2            8180
# 29743                        1           15708
# 29744                        2            7446
#
# [29428 rows x 4 columns]

# %%
general_data['repo_id'] = general_data['full_name'].astype('category').cat.codes

# %%
general_data['language_id'] = general_data['language'].astype('category').cat.codes

# %%
general_data['license_id'] = general_data['license'].astype('category').cat.codes

# %%
general_data
# Out:
#                                          name  \
# 0                                    HyperDbg
# 1                                      octo4a
# 2                                   VIMKiller
# 3                                 OpenSeeFace
# 4      react-typescript-web-extension-starter
# ...                                       ...
# 23995                        seed-wyse-vector
# 23996                         jd_ql_assistant
# 23997        dating_app_moonmeet_react_native
# 23998                                 interim
# 23999                       audiocraft-docker
#
#                                               full_name  \
# 0                                     HyperDbg/HyperDbg
# 1                                  feelfreelinux/octo4a
# 2                                 caseykneale/VIMKiller
# 3                                emilianavt/OpenSeeFace
# 4         aeksco/react-typescript-web-extension-starter
# ...                                                 ...
# 23995                     ruikishimoto/seed-wyse-vector
# 23996                        SSJACK8582/jd_ql_assistant
# 23997  johncoffeeocean/dating_app_moonmeet_react_native
# 23998                                     JD557/interim
# 23999                 ashleykleynhans/audiocraft-docker
#
#                                                      url  \
# 0                   https://github.com/HyperDbg/HyperDbg
# 1                https://github.com/feelfreelinux/octo4a
# 2               https://github.com/caseykneale/VIMKiller
# 3              https://github.com/emilianavt/OpenSeeFace
# 4      https://github.com/aeksco/react-typescript-web...
# ...                                                  ...
# 23995   https://github.com/ruikishimoto/seed-wyse-vector
# 23996      https://github.com/SSJACK8582/jd_ql_assistant
# 23997  https://github.com/johncoffeeocean/dating_app_...
# 23998                   https://github.com/JD557/interim
# 23999  https://github.com/ashleykleynhans/audiocraft-...
#
#                                              description  stars  \
# 0                 State-of-the-art native debugging tool   2173
# 1      Use your old Android device as an OctoPrint se...   1265
# 2      Exiting VIM is hard; sometimes we need to take...   1159
# 3      Robust realtime face and facial landmark track...   1105
# 4      :desktop_computer: Web Extension starter kit b...    805
# ...                                                  ...    ...
# 23995                                     no_description      9
# 23996                                           京东青龙抢购助手      9
# 23997                                     no_description      9
# 23998                   Immediate mode GUI in pure Scala      9
# 23999  Docker image for Audiocraft audio processing a...      8
#
#                       created_at    language  forks  \
# 0      2020-01-01 12:34:32+00:00           C    317
# 1      2020-01-01 17:00:11+00:00      Kotlin    123
# 2      2020-01-01 01:31:29+00:00       Julia     13
# 3      2020-01-01 12:49:35+00:00      Python    134
# 4      2020-01-01 01:14:35+00:00  JavaScript     73
# ...                          ...         ...    ...
# 23995  2023-06-10 02:19:31+00:00         PHP      0
# 23996  2023-06-10 13:05:14+00:00      Python      2
# 23997  2023-06-10 04:59:10+00:00  JavaScript      0
# 23998  2023-06-10 14:38:21+00:00       Scala      1
# 23999  2023-06-10 13:07:46+00:00  Dockerfile      0
#
#                       updated_at  \
# 0      2023-06-23 10:17:49+00:00
# 1      2023-06-21 22:24:04+00:00
# 2      2023-06-21 16:37:23+00:00
# 3      2023-06-23 11:37:45+00:00
# 4      2023-06-18 12:59:14+00:00
# ...                          ...
# 23995  2023-06-23 14:55:57+00:00
# 23996  2023-06-20 07:48:09+00:00
# 23997  2023-06-23 15:01:38+00:00
# 23998  2023-06-19 12:14:26+00:00
# 23999  2023-06-21 03:24:33+00:00
#
#                                                   topics  \
# 0      ['debug', 'debugger', 'ept', 'hook', 'hyperdbg...
# 1                ['3d-printing', 'android', 'octoprint']
# 2                                                     []
# 3      ['cpu', 'csharp', 'depth-estimation', 'detecti...
# 4      ['brave', 'chrome-extension', 'eslint', 'exten...
# ...                                                  ...
# 23995                                                 []
# 23996                                                 []
# 23997                                                 []
# 23998  ['gui', 'immediate-gui', 'scala', 'scala-js', ...
# 23999                                                 []
#
#                                                  license type_of_owner  \
# 0      {'key': 'gpl-3.0', 'name': 'GNU General Public...  Organization
# 1      {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...          User
# 2      {'key': 'mit', 'name': 'MIT License', 'spdx_id...          User
# 3      {'key': 'bsd-2-clause', 'name': 'BSD 2-Clause ...          User
# 4      {'key': 'mit', 'name': 'MIT License', 'spdx_id...          User
# ...                                                  ...           ...
# 23995  {'key': 'other', 'name': 'Other', 'spdx_id': '...          User
# 23996                                         no_license          User
# 23997  {'key': 'gpl-3.0', 'name': 'GNU General Public...          User
# 23998  {'key': 'mit', 'name': 'MIT License', 'spdx_id...          User
# 23999  {'key': 'gpl-3.0', 'name': 'GNU General Public...          User
#
#        repo_id  language_id  license_id
# 0         2766           18          18
# 1        11741           79           2
# 2         9326           75          23
# 3        11310          121           5
# 4         7317           72          23
# ...        ...          ...         ...
# 23995    19617          111          31
# 23996     5383          121           0
# 23997    14241           72          18
# 23998     2929          137          23
# 23999     8225           42          18
#
# [24000 rows x 15 columns]

# %%
general_data[['owner_Name', 'repo_Name']] = general_data["full_name"].apply(lambda x: pd.Series(str(x).split("/")))

# %%
general_data
# Out:
#                                          name  \
# 0                                    HyperDbg
# 1                                      octo4a
# 2                                   VIMKiller
# 3                                 OpenSeeFace
# 4      react-typescript-web-extension-starter
# ...                                       ...
# 23995                        seed-wyse-vector
# 23996                         jd_ql_assistant
# 23997        dating_app_moonmeet_react_native
# 23998                                 interim
# 23999                       audiocraft-docker
#
#                                               full_name  \
# 0                                     HyperDbg/HyperDbg
# 1                                  feelfreelinux/octo4a
# 2                                 caseykneale/VIMKiller
# 3                                emilianavt/OpenSeeFace
# 4         aeksco/react-typescript-web-extension-starter
# ...                                                 ...
# 23995                     ruikishimoto/seed-wyse-vector
# 23996                        SSJACK8582/jd_ql_assistant
# 23997  johncoffeeocean/dating_app_moonmeet_react_native
# 23998                                     JD557/interim
# 23999                 ashleykleynhans/audiocraft-docker
#
#                                                      url  \
# 0                   https://github.com/HyperDbg/HyperDbg
# 1                https://github.com/feelfreelinux/octo4a
# 2               https://github.com/caseykneale/VIMKiller
# 3              https://github.com/emilianavt/OpenSeeFace
# 4      https://github.com/aeksco/react-typescript-web...
# ...                                                  ...
# 23995   https://github.com/ruikishimoto/seed-wyse-vector
# 23996      https://github.com/SSJACK8582/jd_ql_assistant
# 23997  https://github.com/johncoffeeocean/dating_app_...
# 23998                   https://github.com/JD557/interim
# 23999  https://github.com/ashleykleynhans/audiocraft-...
#
#                                              description  stars  \
# 0                 State-of-the-art native debugging tool   2173
# 1      Use your old Android device as an OctoPrint se...   1265
# 2      Exiting VIM is hard; sometimes we need to take...   1159
# 3      Robust realtime face and facial landmark track...   1105
# 4      :desktop_computer: Web Extension starter kit b...    805
# ...                                                  ...    ...
# 23995                                     no_description      9
# 23996                                           京东青龙抢购助手      9
# 23997                                     no_description      9
# 23998                   Immediate mode GUI in pure Scala      9
# 23999  Docker image for Audiocraft audio processing a...      8
#
#                       created_at    language  forks  \
# 0      2020-01-01 12:34:32+00:00           C    317
# 1      2020-01-01 17:00:11+00:00      Kotlin    123
# 2      2020-01-01 01:31:29+00:00       Julia     13
# 3      2020-01-01 12:49:35+00:00      Python    134
# 4      2020-01-01 01:14:35+00:00  JavaScript     73
# ...                          ...         ...    ...
# 23995  2023-06-10 02:19:31+00:00         PHP      0
# 23996  2023-06-10 13:05:14+00:00      Python      2
# 23997  2023-06-10 04:59:10+00:00  JavaScript      0
# 23998  2023-06-10 14:38:21+00:00       Scala      1
# 23999  2023-06-10 13:07:46+00:00  Dockerfile      0
#
#                       updated_at  \
# 0      2023-06-23 10:17:49+00:00
# 1      2023-06-21 22:24:04+00:00
# 2      2023-06-21 16:37:23+00:00
# 3      2023-06-23 11:37:45+00:00
# 4      2023-06-18 12:59:14+00:00
# ...                          ...
# 23995  2023-06-23 14:55:57+00:00
# 23996  2023-06-20 07:48:09+00:00
# 23997  2023-06-23 15:01:38+00:00
# 23998  2023-06-19 12:14:26+00:00
# 23999  2023-06-21 03:24:33+00:00
#
#                                                   topics  \
# 0      ['debug', 'debugger', 'ept', 'hook', 'hyperdbg...
# 1                ['3d-printing', 'android', 'octoprint']
# 2                                                     []
# 3      ['cpu', 'csharp', 'depth-estimation', 'detecti...
# 4      ['brave', 'chrome-extension', 'eslint', 'exten...
# ...                                                  ...
# 23995                                                 []
# 23996                                                 []
# 23997                                                 []
# 23998  ['gui', 'immediate-gui', 'scala', 'scala-js', ...
# 23999                                                 []
#
#                                                  license type_of_owner  \
# 0      {'key': 'gpl-3.0', 'name': 'GNU General Public...  Organization
# 1      {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...          User
# 2      {'key': 'mit', 'name': 'MIT License', 'spdx_id...          User
# 3      {'key': 'bsd-2-clause', 'name': 'BSD 2-Clause ...          User
# 4      {'key': 'mit', 'name': 'MIT License', 'spdx_id...          User
# ...                                                  ...           ...
# 23995  {'key': 'other', 'name': 'Other', 'spdx_id': '...          User
# 23996                                         no_license          User
# 23997  {'key': 'gpl-3.0', 'name': 'GNU General Public...          User
# 23998  {'key': 'mit', 'name': 'MIT License', 'spdx_id...          User
# 23999  {'key': 'gpl-3.0', 'name': 'GNU General Public...          User
#
#        repo_id  language_id  license_id       owner_Name  \
# 0         2766           18          18         HyperDbg
# 1        11741           79           2    feelfreelinux
# 2         9326           75          23      caseykneale
# 3        11310          121           5       emilianavt
# 4         7317           72          23           aeksco
# ...        ...          ...         ...              ...
# 23995    19617          111          31     ruikishimoto
# 23996     5383          121           0       SSJACK8582
# 23997    14241           72          18  johncoffeeocean
# 23998     2929          137          23            JD557
# 23999     8225           42          18  ashleykleynhans
#
#                                     repo_Name
# 0                                    HyperDbg
# 1                                      octo4a
# 2                                   VIMKiller
# 3                                 OpenSeeFace
# 4      react-typescript-web-extension-starter
# ...                                       ...
# 23995                        seed-wyse-vector
# 23996                         jd_ql_assistant
# 23997        dating_app_moonmeet_react_native
# 23998                                 interim
# 23999                       audiocraft-docker
#
# [24000 rows x 17 columns]

# %%
df_exploded = general_data.explode('topics')

# Reset the index of the exploded data frame
df_exploded = df_exploded.reset_index(drop=True)

print(df_exploded)
# Out:
#                                          name  \
# 0                                    HyperDbg
# 1                                      octo4a
# 2                                   VIMKiller
# 3                                 OpenSeeFace
# 4      react-typescript-web-extension-starter
# ...                                       ...
# 23995                        seed-wyse-vector
# 23996                         jd_ql_assistant
# 23997        dating_app_moonmeet_react_native
# 23998                                 interim
# 23999                       audiocraft-docker
#
#                                               full_name  \
# 0                                     HyperDbg/HyperDbg
# 1                                  feelfreelinux/octo4a
# 2                                 caseykneale/VIMKiller
# 3                                emilianavt/OpenSeeFace
# 4         aeksco/react-typescript-web-extension-starter
# ...                                                 ...
# 23995                     ruikishimoto/seed-wyse-vector
# 23996                        SSJACK8582/jd_ql_assistant
# 23997  johncoffeeocean/dating_app_moonmeet_react_native
# 23998                                     JD557/interim
# 23999                 ashleykleynhans/audiocraft-docker
#
#                                                      url  \
# 0                   https://github.com/HyperDbg/HyperDbg
# 1                https://github.com/feelfreelinux/octo4a
# 2               https://github.com/caseykneale/VIMKiller
# 3              https://github.com/emilianavt/OpenSeeFace
# 4      https://github.com/aeksco/react-typescript-web...
# ...                                                  ...
# 23995   https://github.com/ruikishimoto/seed-wyse-vector
# 23996      https://github.com/SSJACK8582/jd_ql_assistant
# 23997  https://github.com/johncoffeeocean/dating_app_...
# 23998                   https://github.com/JD557/interim
# 23999  https://github.com/ashleykleynhans/audiocraft-...
#
#                                              description  stars  \
# 0                 State-of-the-art native debugging tool   2173
# 1      Use your old Android device as an OctoPrint se...   1265
# 2      Exiting VIM is hard; sometimes we need to take...   1159
# 3      Robust realtime face and facial landmark track...   1105
# 4      :desktop_computer: Web Extension starter kit b...    805
# ...                                                  ...    ...
# 23995                                     no_description      9
# 23996                                           京东青龙抢购助手      9
# 23997                                     no_description      9
# 23998                   Immediate mode GUI in pure Scala      9
# 23999  Docker image for Audiocraft audio processing a...      8
#
#                       created_at    language  forks  \
# 0      2020-01-01 12:34:32+00:00           C    317
# 1      2020-01-01 17:00:11+00:00      Kotlin    123
# 2      2020-01-01 01:31:29+00:00       Julia     13
# 3      2020-01-01 12:49:35+00:00      Python    134
# 4      2020-01-01 01:14:35+00:00  JavaScript     73
# ...                          ...         ...    ...
# 23995  2023-06-10 02:19:31+00:00         PHP      0
# 23996  2023-06-10 13:05:14+00:00      Python      2
# 23997  2023-06-10 04:59:10+00:00  JavaScript      0
# 23998  2023-06-10 14:38:21+00:00       Scala      1
# 23999  2023-06-10 13:07:46+00:00  Dockerfile      0
#
#                       updated_at  \
# 0      2023-06-23 10:17:49+00:00
# 1      2023-06-21 22:24:04+00:00
# 2      2023-06-21 16:37:23+00:00
# 3      2023-06-23 11:37:45+00:00
# 4      2023-06-18 12:59:14+00:00
# ...                          ...
# 23995  2023-06-23 14:55:57+00:00
# 23996  2023-06-20 07:48:09+00:00
# 23997  2023-06-23 15:01:38+00:00
# 23998  2023-06-19 12:14:26+00:00
# 23999  2023-06-21 03:24:33+00:00
#
#                                                   topics  \
# 0      ['debug', 'debugger', 'ept', 'hook', 'hyperdbg...
# 1                ['3d-printing', 'android', 'octoprint']
# 2                                                     []
# 3      ['cpu', 'csharp', 'depth-estimation', 'detecti...
# 4      ['brave', 'chrome-extension', 'eslint', 'exten...
# ...                                                  ...
# 23995                                                 []
# 23996                                                 []
# 23997                                                 []
# 23998  ['gui', 'immediate-gui', 'scala', 'scala-js', ...
# 23999                                                 []
#
#                                                  license type_of_owner  \
# 0      {'key': 'gpl-3.0', 'name': 'GNU General Public...  Organization
# 1      {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...          User
# 2      {'key': 'mit', 'name': 'MIT License', 'spdx_id...          User
# 3      {'key': 'bsd-2-clause', 'name': 'BSD 2-Clause ...          User
# 4      {'key': 'mit', 'name': 'MIT License', 'spdx_id...          User
# ...                                                  ...           ...
# 23995  {'key': 'other', 'name': 'Other', 'spdx_id': '...          User
# 23996                                         no_license          User
# 23997  {'key': 'gpl-3.0', 'name': 'GNU General Public...          User
# 23998  {'key': 'mit', 'name': 'MIT License', 'spdx_id...          User
# 23999  {'key': 'gpl-3.0', 'name': 'GNU General Public...          User
#
#        repo_id  language_id  license_id       owner_Name  \
# 0         2766           18          18         HyperDbg
# 1        11741           79           2    feelfreelinux
# 2         9326           75          23      caseykneale
# 3        11310          121           5       emilianavt
# 4         7317           72          23           aeksco
# ...        ...          ...         ...              ...
# 23995    19617          111          31     ruikishimoto
# 23996     5383          121           0       SSJACK8582
# 23997    14241           72          18  johncoffeeocean
# 23998     2929          137          23            JD557
# 23999     8225           42          18  ashleykleynhans
#
#                                     repo_Name
# 0                                    HyperDbg
# 1                                      octo4a
# 2                                   VIMKiller
# 3                                 OpenSeeFace
# 4      react-typescript-web-extension-starter
# ...                                       ...
# 23995                        seed-wyse-vector
# 23996                         jd_ql_assistant
# 23997        dating_app_moonmeet_react_native
# 23998                                 interim
# 23999                       audiocraft-docker
#
# [24000 rows x 17 columns]

# %%
df_exploded
# Out:
#                                          name  \
# 0                                    HyperDbg
# 1                                      octo4a
# 2                                   VIMKiller
# 3                                 OpenSeeFace
# 4      react-typescript-web-extension-starter
# ...                                       ...
# 23995                        seed-wyse-vector
# 23996                         jd_ql_assistant
# 23997        dating_app_moonmeet_react_native
# 23998                                 interim
# 23999                       audiocraft-docker
#
#                                               full_name  \
# 0                                     HyperDbg/HyperDbg
# 1                                  feelfreelinux/octo4a
# 2                                 caseykneale/VIMKiller
# 3                                emilianavt/OpenSeeFace
# 4         aeksco/react-typescript-web-extension-starter
# ...                                                 ...
# 23995                     ruikishimoto/seed-wyse-vector
# 23996                        SSJACK8582/jd_ql_assistant
# 23997  johncoffeeocean/dating_app_moonmeet_react_native
# 23998                                     JD557/interim
# 23999                 ashleykleynhans/audiocraft-docker
#
#                                                      url  \
# 0                   https://github.com/HyperDbg/HyperDbg
# 1                https://github.com/feelfreelinux/octo4a
# 2               https://github.com/caseykneale/VIMKiller
# 3              https://github.com/emilianavt/OpenSeeFace
# 4      https://github.com/aeksco/react-typescript-web...
# ...                                                  ...
# 23995   https://github.com/ruikishimoto/seed-wyse-vector
# 23996      https://github.com/SSJACK8582/jd_ql_assistant
# 23997  https://github.com/johncoffeeocean/dating_app_...
# 23998                   https://github.com/JD557/interim
# 23999  https://github.com/ashleykleynhans/audiocraft-...
#
#                                              description  stars  \
# 0                 State-of-the-art native debugging tool   2173
# 1      Use your old Android device as an OctoPrint se...   1265
# 2      Exiting VIM is hard; sometimes we need to take...   1159
# 3      Robust realtime face and facial landmark track...   1105
# 4      :desktop_computer: Web Extension starter kit b...    805
# ...                                                  ...    ...
# 23995                                     no_description      9
# 23996                                           京东青龙抢购助手      9
# 23997                                     no_description      9
# 23998                   Immediate mode GUI in pure Scala      9
# 23999  Docker image for Audiocraft audio processing a...      8
#
#                       created_at    language  forks  \
# 0      2020-01-01 12:34:32+00:00           C    317
# 1      2020-01-01 17:00:11+00:00      Kotlin    123
# 2      2020-01-01 01:31:29+00:00       Julia     13
# 3      2020-01-01 12:49:35+00:00      Python    134
# 4      2020-01-01 01:14:35+00:00  JavaScript     73
# ...                          ...         ...    ...
# 23995  2023-06-10 02:19:31+00:00         PHP      0
# 23996  2023-06-10 13:05:14+00:00      Python      2
# 23997  2023-06-10 04:59:10+00:00  JavaScript      0
# 23998  2023-06-10 14:38:21+00:00       Scala      1
# 23999  2023-06-10 13:07:46+00:00  Dockerfile      0
#
#                       updated_at  \
# 0      2023-06-23 10:17:49+00:00
# 1      2023-06-21 22:24:04+00:00
# 2      2023-06-21 16:37:23+00:00
# 3      2023-06-23 11:37:45+00:00
# 4      2023-06-18 12:59:14+00:00
# ...                          ...
# 23995  2023-06-23 14:55:57+00:00
# 23996  2023-06-20 07:48:09+00:00
# 23997  2023-06-23 15:01:38+00:00
# 23998  2023-06-19 12:14:26+00:00
# 23999  2023-06-21 03:24:33+00:00
#
#                                                   topics  \
# 0      ['debug', 'debugger', 'ept', 'hook', 'hyperdbg...
# 1                ['3d-printing', 'android', 'octoprint']
# 2                                                     []
# 3      ['cpu', 'csharp', 'depth-estimation', 'detecti...
# 4      ['brave', 'chrome-extension', 'eslint', 'exten...
# ...                                                  ...
# 23995                                                 []
# 23996                                                 []
# 23997                                                 []
# 23998  ['gui', 'immediate-gui', 'scala', 'scala-js', ...
# 23999                                                 []
#
#                                                  license type_of_owner  \
# 0      {'key': 'gpl-3.0', 'name': 'GNU General Public...  Organization
# 1      {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...          User
# 2      {'key': 'mit', 'name': 'MIT License', 'spdx_id...          User
# 3      {'key': 'bsd-2-clause', 'name': 'BSD 2-Clause ...          User
# 4      {'key': 'mit', 'name': 'MIT License', 'spdx_id...          User
# ...                                                  ...           ...
# 23995  {'key': 'other', 'name': 'Other', 'spdx_id': '...          User
# 23996                                         no_license          User
# 23997  {'key': 'gpl-3.0', 'name': 'GNU General Public...          User
# 23998  {'key': 'mit', 'name': 'MIT License', 'spdx_id...          User
# 23999  {'key': 'gpl-3.0', 'name': 'GNU General Public...          User
#
#        repo_id  language_id  license_id       owner_Name  \
# 0         2766           18          18         HyperDbg
# 1        11741           79           2    feelfreelinux
# 2         9326           75          23      caseykneale
# 3        11310          121           5       emilianavt
# 4         7317           72          23           aeksco
# ...        ...          ...         ...              ...
# 23995    19617          111          31     ruikishimoto
# 23996     5383          121           0       SSJACK8582
# 23997    14241           72          18  johncoffeeocean
# 23998     2929          137          23            JD557
# 23999     8225           42          18  ashleykleynhans
#
#                                     repo_Name
# 0                                    HyperDbg
# 1                                      octo4a
# 2                                   VIMKiller
# 3                                 OpenSeeFace
# 4      react-typescript-web-extension-starter
# ...                                       ...
# 23995                        seed-wyse-vector
# 23996                         jd_ql_assistant
# 23997        dating_app_moonmeet_react_native
# 23998                                 interim
# 23999                       audiocraft-docker
#
# [24000 rows x 17 columns]

# %%
data = general_data
df = pd.DataFrame(data)

# Convert the strings back to lists using ast.literal_eval
df['topics'] = df['topics'].apply(ast.literal_eval)

# Explode the 'topics' column to split the lists into individual elements
df_exploded = df.explode('topics')

# Reset the index of the exploded data frame
df_exploded = df_exploded.reset_index(drop=True)
# Out:
#                     name                          full_name  \
# 0               HyperDbg                  HyperDbg/HyperDbg
# 1               HyperDbg                  HyperDbg/HyperDbg
# 2               HyperDbg                  HyperDbg/HyperDbg
# 3               HyperDbg                  HyperDbg/HyperDbg
# 4               HyperDbg                  HyperDbg/HyperDbg
# ...                  ...                                ...
# 96288            interim                      JD557/interim
# 96289            interim                      JD557/interim
# 96290            interim                      JD557/interim
# 96291            interim                      JD557/interim
# 96292  audiocraft-docker  ashleykleynhans/audiocraft-docker
#
#                                                      url  \
# 0                   https://github.com/HyperDbg/HyperDbg
# 1                   https://github.com/HyperDbg/HyperDbg
# 2                   https://github.com/HyperDbg/HyperDbg
# 3                   https://github.com/HyperDbg/HyperDbg
# 4                   https://github.com/HyperDbg/HyperDbg
# ...                                                  ...
# 96288                   https://github.com/JD557/interim
# 96289                   https://github.com/JD557/interim
# 96290                   https://github.com/JD557/interim
# 96291                   https://github.com/JD557/interim
# 96292  https://github.com/ashleykleynhans/audiocraft-...
#
#                                              description  stars  \
# 0                 State-of-the-art native debugging tool   2173
# 1                 State-of-the-art native debugging tool   2173
# 2                 State-of-the-art native debugging tool   2173
# 3                 State-of-the-art native debugging tool   2173
# 4                 State-of-the-art native debugging tool   2173
# ...                                                  ...    ...
# 96288                   Immediate mode GUI in pure Scala      9
# 96289                   Immediate mode GUI in pure Scala      9
# 96290                   Immediate mode GUI in pure Scala      9
# 96291                   Immediate mode GUI in pure Scala      9
# 96292  Docker image for Audiocraft audio processing a...      8
#
#                       created_at    language  forks  \
# 0      2020-01-01 12:34:32+00:00           C    317
# 1      2020-01-01 12:34:32+00:00           C    317
# 2      2020-01-01 12:34:32+00:00           C    317
# 3      2020-01-01 12:34:32+00:00           C    317
# 4      2020-01-01 12:34:32+00:00           C    317
# ...                          ...         ...    ...
# 96288  2023-06-10 14:38:21+00:00       Scala      1
# 96289  2023-06-10 14:38:21+00:00       Scala      1
# 96290  2023-06-10 14:38:21+00:00       Scala      1
# 96291  2023-06-10 14:38:21+00:00       Scala      1
# 96292  2023-06-10 13:07:46+00:00  Dockerfile      0
#
#                       updated_at         topics  \
# 0      2023-06-23 10:17:49+00:00          debug
# 1      2023-06-23 10:17:49+00:00       debugger
# 2      2023-06-23 10:17:49+00:00            ept
# 3      2023-06-23 10:17:49+00:00           hook
# 4      2023-06-23 10:17:49+00:00       hyperdbg
# ...                          ...            ...
# 96288  2023-06-19 12:14:26+00:00  immediate-gui
# 96289  2023-06-19 12:14:26+00:00          scala
# 96290  2023-06-19 12:14:26+00:00       scala-js
# 96291  2023-06-19 12:14:26+00:00   scala-native
# 96292  2023-06-21 03:24:33+00:00            NaN
#
#                                                  license type_of_owner  \
# 0      {'key': 'gpl-3.0', 'name': 'GNU General Public...  Organization
# 1      {'key': 'gpl-3.0', 'name': 'GNU General Public...  Organization
# 2      {'key': 'gpl-3.0', 'name': 'GNU General Public...  Organization
# 3      {'key': 'gpl-3.0', 'name': 'GNU General Public...  Organization
# 4      {'key': 'gpl-3.0', 'name': 'GNU General Public...  Organization
# ...                                                  ...           ...
# 96288  {'key': 'mit', 'name': 'MIT License', 'spdx_id...          User
# 96289  {'key': 'mit', 'name': 'MIT License', 'spdx_id...          User
# 96290  {'key': 'mit', 'name': 'MIT License', 'spdx_id...          User
# 96291  {'key': 'mit', 'name': 'MIT License', 'spdx_id...          User
# 96292  {'key': 'gpl-3.0', 'name': 'GNU General Public...          User
#
#        repo_id  language_id  license_id       owner_Name          repo_Name
# 0         2766           18          18         HyperDbg           HyperDbg
# 1         2766           18          18         HyperDbg           HyperDbg
# 2         2766           18          18         HyperDbg           HyperDbg
# 3         2766           18          18         HyperDbg           HyperDbg
# 4         2766           18          18         HyperDbg           HyperDbg
# ...        ...          ...         ...              ...                ...
# 96288     2929          137          23            JD557            interim
# 96289     2929          137          23            JD557            interim
# 96290     2929          137          23            JD557            interim
# 96291     2929          137          23            JD557            interim
# 96292     8225           42          18  ashleykleynhans  audiocraft-docker
#
# [96293 rows x 17 columns]

# %%
df_exploded["topics"].fillna('no topics', inplace=True)

# %%
general_data
# Out:
#                                          name  \
# 0                                    HyperDbg
# 1                                      octo4a
# 2                                   VIMKiller
# 3                                 OpenSeeFace
# 4      react-typescript-web-extension-starter
# ...                                       ...
# 23995                        seed-wyse-vector
# 23996                         jd_ql_assistant
# 23997        dating_app_moonmeet_react_native
# 23998                                 interim
# 23999                       audiocraft-docker
#
#                                               full_name  \
# 0                                     HyperDbg/HyperDbg
# 1                                  feelfreelinux/octo4a
# 2                                 caseykneale/VIMKiller
# 3                                emilianavt/OpenSeeFace
# 4         aeksco/react-typescript-web-extension-starter
# ...                                                 ...
# 23995                     ruikishimoto/seed-wyse-vector
# 23996                        SSJACK8582/jd_ql_assistant
# 23997  johncoffeeocean/dating_app_moonmeet_react_native
# 23998                                     JD557/interim
# 23999                 ashleykleynhans/audiocraft-docker
#
#                                                      url  \
# 0                   https://github.com/HyperDbg/HyperDbg
# 1                https://github.com/feelfreelinux/octo4a
# 2               https://github.com/caseykneale/VIMKiller
# 3              https://github.com/emilianavt/OpenSeeFace
# 4      https://github.com/aeksco/react-typescript-web...
# ...                                                  ...
# 23995   https://github.com/ruikishimoto/seed-wyse-vector
# 23996      https://github.com/SSJACK8582/jd_ql_assistant
# 23997  https://github.com/johncoffeeocean/dating_app_...
# 23998                   https://github.com/JD557/interim
# 23999  https://github.com/ashleykleynhans/audiocraft-...
#
#                                              description  stars  \
# 0                 State-of-the-art native debugging tool   2173
# 1      Use your old Android device as an OctoPrint se...   1265
# 2      Exiting VIM is hard; sometimes we need to take...   1159
# 3      Robust realtime face and facial landmark track...   1105
# 4      :desktop_computer: Web Extension starter kit b...    805
# ...                                                  ...    ...
# 23995                                     no_description      9
# 23996                                           京东青龙抢购助手      9
# 23997                                     no_description      9
# 23998                   Immediate mode GUI in pure Scala      9
# 23999  Docker image for Audiocraft audio processing a...      8
#
#                       created_at    language  forks  \
# 0      2020-01-01 12:34:32+00:00           C    317
# 1      2020-01-01 17:00:11+00:00      Kotlin    123
# 2      2020-01-01 01:31:29+00:00       Julia     13
# 3      2020-01-01 12:49:35+00:00      Python    134
# 4      2020-01-01 01:14:35+00:00  JavaScript     73
# ...                          ...         ...    ...
# 23995  2023-06-10 02:19:31+00:00         PHP      0
# 23996  2023-06-10 13:05:14+00:00      Python      2
# 23997  2023-06-10 04:59:10+00:00  JavaScript      0
# 23998  2023-06-10 14:38:21+00:00       Scala      1
# 23999  2023-06-10 13:07:46+00:00  Dockerfile      0
#
#                       updated_at  \
# 0      2023-06-23 10:17:49+00:00
# 1      2023-06-21 22:24:04+00:00
# 2      2023-06-21 16:37:23+00:00
# 3      2023-06-23 11:37:45+00:00
# 4      2023-06-18 12:59:14+00:00
# ...                          ...
# 23995  2023-06-23 14:55:57+00:00
# 23996  2023-06-20 07:48:09+00:00
# 23997  2023-06-23 15:01:38+00:00
# 23998  2023-06-19 12:14:26+00:00
# 23999  2023-06-21 03:24:33+00:00
#
#                                                   topics  \
# 0      [debug, debugger, ept, hook, hyperdbg, hypervi...
# 1                      [3d-printing, android, octoprint]
# 2                                                     []
# 3      [cpu, csharp, depth-estimation, detection-mode...
# 4      [brave, chrome-extension, eslint, extension-po...
# ...                                                  ...
# 23995                                                 []
# 23996                                                 []
# 23997                                                 []
# 23998  [gui, immediate-gui, scala, scala-js, scala-na...
# 23999                                                 []
#
#                                                  license type_of_owner  \
# 0      {'key': 'gpl-3.0', 'name': 'GNU General Public...  Organization
# 1      {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...          User
# 2      {'key': 'mit', 'name': 'MIT License', 'spdx_id...          User
# 3      {'key': 'bsd-2-clause', 'name': 'BSD 2-Clause ...          User
# 4      {'key': 'mit', 'name': 'MIT License', 'spdx_id...          User
# ...                                                  ...           ...
# 23995  {'key': 'other', 'name': 'Other', 'spdx_id': '...          User
# 23996                                         no_license          User
# 23997  {'key': 'gpl-3.0', 'name': 'GNU General Public...          User
# 23998  {'key': 'mit', 'name': 'MIT License', 'spdx_id...          User
# 23999  {'key': 'gpl-3.0', 'name': 'GNU General Public...          User
#
#        repo_id  language_id  license_id       owner_Name  \
# 0         2766           18          18         HyperDbg
# 1        11741           79           2    feelfreelinux
# 2         9326           75          23      caseykneale
# 3        11310          121           5       emilianavt
# 4         7317           72          23           aeksco
# ...        ...          ...         ...              ...
# 23995    19617          111          31     ruikishimoto
# 23996     5383          121           0       SSJACK8582
# 23997    14241           72          18  johncoffeeocean
# 23998     2929          137          23            JD557
# 23999     8225           42          18  ashleykleynhans
#
#                                     repo_Name
# 0                                    HyperDbg
# 1                                      octo4a
# 2                                   VIMKiller
# 3                                 OpenSeeFace
# 4      react-typescript-web-extension-starter
# ...                                       ...
# 23995                        seed-wyse-vector
# 23996                         jd_ql_assistant
# 23997        dating_app_moonmeet_react_native
# 23998                                 interim
# 23999                       audiocraft-docker
#
# [24000 rows x 17 columns]

# %%
df_exploded
# Out:
#                     name                          full_name  \
# 0               HyperDbg                  HyperDbg/HyperDbg
# 1               HyperDbg                  HyperDbg/HyperDbg
# 2               HyperDbg                  HyperDbg/HyperDbg
# 3               HyperDbg                  HyperDbg/HyperDbg
# 4               HyperDbg                  HyperDbg/HyperDbg
# ...                  ...                                ...
# 96288            interim                      JD557/interim
# 96289            interim                      JD557/interim
# 96290            interim                      JD557/interim
# 96291            interim                      JD557/interim
# 96292  audiocraft-docker  ashleykleynhans/audiocraft-docker
#
#                                                      url  \
# 0                   https://github.com/HyperDbg/HyperDbg
# 1                   https://github.com/HyperDbg/HyperDbg
# 2                   https://github.com/HyperDbg/HyperDbg
# 3                   https://github.com/HyperDbg/HyperDbg
# 4                   https://github.com/HyperDbg/HyperDbg
# ...                                                  ...
# 96288                   https://github.com/JD557/interim
# 96289                   https://github.com/JD557/interim
# 96290                   https://github.com/JD557/interim
# 96291                   https://github.com/JD557/interim
# 96292  https://github.com/ashleykleynhans/audiocraft-...
#
#                                              description  stars  \
# 0                 State-of-the-art native debugging tool   2173
# 1                 State-of-the-art native debugging tool   2173
# 2                 State-of-the-art native debugging tool   2173
# 3                 State-of-the-art native debugging tool   2173
# 4                 State-of-the-art native debugging tool   2173
# ...                                                  ...    ...
# 96288                   Immediate mode GUI in pure Scala      9
# 96289                   Immediate mode GUI in pure Scala      9
# 96290                   Immediate mode GUI in pure Scala      9
# 96291                   Immediate mode GUI in pure Scala      9
# 96292  Docker image for Audiocraft audio processing a...      8
#
#                       created_at    language  forks  \
# 0      2020-01-01 12:34:32+00:00           C    317
# 1      2020-01-01 12:34:32+00:00           C    317
# 2      2020-01-01 12:34:32+00:00           C    317
# 3      2020-01-01 12:34:32+00:00           C    317
# 4      2020-01-01 12:34:32+00:00           C    317
# ...                          ...         ...    ...
# 96288  2023-06-10 14:38:21+00:00       Scala      1
# 96289  2023-06-10 14:38:21+00:00       Scala      1
# 96290  2023-06-10 14:38:21+00:00       Scala      1
# 96291  2023-06-10 14:38:21+00:00       Scala      1
# 96292  2023-06-10 13:07:46+00:00  Dockerfile      0
#
#                       updated_at         topics  \
# 0      2023-06-23 10:17:49+00:00          debug
# 1      2023-06-23 10:17:49+00:00       debugger
# 2      2023-06-23 10:17:49+00:00            ept
# 3      2023-06-23 10:17:49+00:00           hook
# 4      2023-06-23 10:17:49+00:00       hyperdbg
# ...                          ...            ...
# 96288  2023-06-19 12:14:26+00:00  immediate-gui
# 96289  2023-06-19 12:14:26+00:00          scala
# 96290  2023-06-19 12:14:26+00:00       scala-js
# 96291  2023-06-19 12:14:26+00:00   scala-native
# 96292  2023-06-21 03:24:33+00:00      no topics
#
#                                                  license type_of_owner  \
# 0      {'key': 'gpl-3.0', 'name': 'GNU General Public...  Organization
# 1      {'key': 'gpl-3.0', 'name': 'GNU General Public...  Organization
# 2      {'key': 'gpl-3.0', 'name': 'GNU General Public...  Organization
# 3      {'key': 'gpl-3.0', 'name': 'GNU General Public...  Organization
# 4      {'key': 'gpl-3.0', 'name': 'GNU General Public...  Organization
# ...                                                  ...           ...
# 96288  {'key': 'mit', 'name': 'MIT License', 'spdx_id...          User
# 96289  {'key': 'mit', 'name': 'MIT License', 'spdx_id...          User
# 96290  {'key': 'mit', 'name': 'MIT License', 'spdx_id...          User
# 96291  {'key': 'mit', 'name': 'MIT License', 'spdx_id...          User
# 96292  {'key': 'gpl-3.0', 'name': 'GNU General Public...          User
#
#        repo_id  language_id  license_id       owner_Name          repo_Name
# 0         2766           18          18         HyperDbg           HyperDbg
# 1         2766           18          18         HyperDbg           HyperDbg
# 2         2766           18          18         HyperDbg           HyperDbg
# 3         2766           18          18         HyperDbg           HyperDbg
# 4         2766           18          18         HyperDbg           HyperDbg
# ...        ...          ...         ...              ...                ...
# 96288     2929          137          23            JD557            interim
# 96289     2929          137          23            JD557            interim
# 96290     2929          137          23            JD557            interim
# 96291     2929          137          23            JD557            interim
# 96292     8225           42          18  ashleykleynhans  audiocraft-docker
#
# [96293 rows x 17 columns]
